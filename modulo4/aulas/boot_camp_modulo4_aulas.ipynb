# %% [markdown]
# <a href="https://colab.research.google.com/github/HenriqueCCdA/bootCampAluraDataScience/blob/master/modulo4/aulas/boot_camp_modulo4_aulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kaggle = False
if kaggle:
  import os
  for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
  # !pip install xlrd==1.2.0
  path = "/kaggle/input/covid19/Kaggle_Sirio_Libanes_ICU_Prediction.xlsx"

else:
  path = "https://github.com/HenriqueCCdA/bootCampAluraDataScience/blob/master/modulo4/dados/Kaggle_Sirio_Libanes_ICU_Prediction.xlsx?raw=true"

# %%
import pandas as pd

dados = pd.read_excel(path)
dados.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
dados.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1925.000000  ...  1925.000000
# mean                 192.000000  ...     0.267532
# std                  111.168431  ...     0.442787
# min                    0.000000  ...     0.000000
# 25%                   96.000000  ...     0.000000
# 50%                  192.000000  ...     0.000000
# 75%                  288.000000  ...     1.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %% [markdown]
# # ICU - Intensive care unit

# %%
dados['ICU']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1920    0
# 1921    0
# 1922    0
# 1923    0
# 1924    0
# Name: ICU, Length: 1925, dtype: int64

# %%
dados['ICU'].value_counts()
# Out:
# 0    1410
# 1     515
# Name: ICU, dtype: int64

# %% [markdown]
# # Aula 3

# %%
x_columns = dados.describe().columns # apenas colunas com float

dados_limpos = dados.dropna()

# %%
y = dados_limpos['ICU']
x = dados_limpos[x_columns].drop(["ICU"], axis=True)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression()
modelo.fit(x, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
sum(modelo.predict(x) == y)
# Out:
# 497

# %%
sum(modelo.predict(x) != y)
# Out:
# 48

# %%
accuracy = sum(modelo.predict(x) == y) / len(y) * 100
print(accuracy)
# Out:
# 91.19266055045871

# %% [markdown]
# # Aula4

# %%
y.value_counts()
# Out:
# 0    281
# 1    264
# Name: ICU, dtype: int64

# %%
from sklearn.dummy import DummyClassifier

modelo = DummyClassifier(strategy='most_frequent')

modelo.fit(x, y)

sum(modelo.predict(x) == y) / len(y) * 100
# Out:
# 51.559633027522935

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y, modelo.predict(x))
# Out:
# 0.5155963302752293

# %%
from sklearn.model_selection import train_test_split
import numpy as np

np.random.seed(73246)

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)

# %%
print(len(x_train), len(y_train))
print(len(x_test), len(y_test))
# Out:
# 408 408
# 137 137

# %%
modelo = LogisticRegression()
modelo.fit(x_train, y_train)
y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.8248175182481752

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.514706
# 1    0.485294
# Name: ICU, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.518248
# 1    0.481752
# Name: ICU, dtype: float64

# %% [markdown]
# # Aula 5

# %%
dados_fake = pd.DataFrame([ [1, None, 1], [1,  2.5, 2], 
                            [2,  3.0, 1], [2, None, 2],
                            [3, None, 1], [3,    1, 2], [3,    None, 3],
                            [4, None, 1], [4, 6.0 , 2], [4,    None, 3], [4,    5.0, 4], [4,    None, 4]                              
                          ], 
                          columns = ["usuario", "medida", "janela"])
dados_fake
# Out:
#     usuario  medida  janela
# 0         1     NaN       1
# 1         1     2.5       2
# 2         2     3.0       1
# 3         2     NaN       2
# 4         3     NaN       1
# 5         3     1.0       2
# 6         3     NaN       3
# 7         4     NaN       1
# 8         4     6.0       2
# 9         4     NaN       3
# 10        4     5.0       4
# 11        4     NaN       4

# %%
dados_fake.groupby('usuario', as_index=False).fillna(method='ffill').fillna(method='bfill')
# Out:
#     medida  janela
# 0      2.5       1
# 1      2.5       2
# 2      3.0       1
# 3      3.0       2
# 4      1.0       1
# 5      1.0       2
# 6      1.0       3
# 7      6.0       1
# 8      6.0       2
# 9      6.0       3
# 10     5.0       4
# 11     5.0       4

# %%
dados.head(20)
# Out:
#     PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                          0            1  ...       0-2    0
# 1                          0            1  ...       2-4    0
# 2                          0            1  ...       4-6    0
# 3                          0            1  ...      6-12    0
# 4                          0            1  ...  ABOVE_12    1
# 5                          1            1  ...       0-2    1
# 6                          1            1  ...       2-4    1
# 7                          1            1  ...       4-6    1
# 8                          1            1  ...      6-12    1
# 9                          1            1  ...  ABOVE_12    1
# 10                         2            0  ...       0-2    0
# 11                         2            0  ...       2-4    0
# 12                         2            0  ...       4-6    0
# 13                         2            0  ...      6-12    0
# ...

# %%
dados = pd.read_excel(path)
dados.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
features_continuas = dados.iloc[:, 13:-2].columns
features_continuas
# Out:
# Index(['ALBUMIN_MEDIAN', 'ALBUMIN_MEAN', 'ALBUMIN_MIN', 'ALBUMIN_MAX',
#        'ALBUMIN_DIFF', 'BE_ARTERIAL_MEDIAN', 'BE_ARTERIAL_MEAN',
#        'BE_ARTERIAL_MIN', 'BE_ARTERIAL_MAX', 'BE_ARTERIAL_DIFF',
#        ...
#        'HEART_RATE_DIFF', 'RESPIRATORY_RATE_DIFF', 'TEMPERATURE_DIFF',
#        'OXYGEN_SATURATION_DIFF', 'BLOODPRESSURE_DIASTOLIC_DIFF_REL',
#        'BLOODPRESSURE_SISTOLIC_DIFF_REL', 'HEART_RATE_DIFF_REL',
#        'RESPIRATORY_RATE_DIFF_REL', 'TEMPERATURE_DIFF_REL',
#        'OXYGEN_SATURATION_DIFF_REL'],
#       dtype='object', length=216)

# %%
def preenche_table(dados):
    
    features_continuas_colunas = dados.iloc[:, 13:-2].columns
   
    features_continuas = dados.groupby("PATIENT_VISIT_IDENTIFIER", as_index=False)[features_continuas_colunas].fillna(method='bfill').fillna(method='ffill')
    
    features_categoricas = dados.iloc[:, :13]
    
    saida = dados.iloc[:,-2:]
    
    dados_finais = pd.concat([features_categoricas, features_continuas,  saida], ignore_index=True, axis=1)
    
    dados_finais.columns = dados.columns
    
    return dados_finais

# %%
dados_limpos = preenche_table(dados)
dados_limpos.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
dados_limpos.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1925.000000  ...  1925.000000
# mean                 192.000000  ...     0.267532
# std                  111.168431  ...     0.442787
# min                    0.000000  ...     0.000000
# 25%                   96.000000  ...     0.000000
# 50%                  192.000000  ...     0.000000
# 75%                  288.000000  ...     1.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %%
dados_limpos = dados_limpos.dropna()

# %%
a_remover = dados_limpos.query('WINDOW=="0-2" and ICU==1')['PATIENT_VISIT_IDENTIFIER'].values

# %%
dados_limpos = dados_limpos.query('PATIENT_VISIT_IDENTIFIER not in @ a_remover')
dados_limpos.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
dados_limpos.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1760.000000  ...  1760.000000
# mean                 192.818182  ...     0.201705
# std                  110.637724  ...     0.401387
# min                    0.000000  ...     0.000000
# 25%                   97.750000  ...     0.000000
# 50%                  191.500000  ...     0.000000
# 75%                  289.250000  ...     0.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %%
dados_limpos.columns[0:20]
# Out:
# Index(['PATIENT_VISIT_IDENTIFIER', 'AGE_ABOVE65', 'AGE_PERCENTIL', 'GENDER',
#        'DISEASE GROUPING 1', 'DISEASE GROUPING 2', 'DISEASE GROUPING 3',
#        'DISEASE GROUPING 4', 'DISEASE GROUPING 5', 'DISEASE GROUPING 6', 'HTN',
#        'IMMUNOCOMPROMISED', 'OTHER', 'ALBUMIN_MEDIAN', 'ALBUMIN_MEAN',
#        'ALBUMIN_MIN', 'ALBUMIN_MAX', 'ALBUMIN_DIFF', 'BE_ARTERIAL_MEDIAN',
#        'BE_ARTERIAL_MEAN'],
#       dtype='object')

# %%
def prepare_window(rows):
    if np.any(rows['ICU']):
        rows.loc[rows['WINDOW'] == '0-2', 'ICU'] = 1
    return rows.loc[rows['WINDOW'] == '0-2']

dados_limpos = dados_limpos.groupby('PATIENT_VISIT_IDENTIFIER').apply(prepare_window)

# %%
y = dados_limpos['ICU']
x = dados_limpos[x_columns].drop(["ICU"], axis=True)

# %%
np.random.seed(73246)

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)

# %%
modelo = DummyClassifier("prior")

modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)

accuracy_score(y_test, y_prediction)
# Out:
# 0.5340909090909091

# %%
modelo = LogisticRegression(max_iter=2000)

modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)

accuracy_score(y_test, y_prediction)
# Out:
# 0.7045454545454546

# %%
x_train
# Out:
#                                PATIENT_VISIT_IDENTIFIER  ...  OXYGEN_SATURATION_DIFF_REL
# PATIENT_VISIT_IDENTIFIER                                 ...
# 31                       155                         31  ...                   -1.000000
# 169                      845                        169  ...                   -1.000000
# 133                      665                        133  ...                   -1.000000
# 319                      1595                       319  ...                   -1.000000
# 43                       215                         43  ...                   -1.000000
# ...                                                 ...  ...                         ...
# 220                      1100                       220  ...                   -1.000000
# 5                        25                           5  ...                   -0.980129
# 380                      1900                       380  ...                   -1.000000
# ...

# %%
import sklearn
import numpy

print("numpy  :"  ,numpy.__version__)
print("sklearn:",sklearn.__version__)
# Out:
# numpy  : 1.19.5
# sklearn: 0.22.2.post1
