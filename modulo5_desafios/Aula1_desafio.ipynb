# %% [markdown]
# <a href="https://colab.research.google.com/github/HenriqueCCdA/bootCampAluraDataScience/blob/master/modulo5_desafios/Aula1_desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) Pre-Analise

# %% [markdown]
# ## 1.1) Download da minhas funções

# %%
# !wget https://raw.githubusercontent.com/HenriqueCCdA/bootCampAluraDataScience/master/modulo5/src/limpeza_dos_dados.py
# Out:
# --2021-07-24 22:54:39--  https://raw.githubusercontent.com/HenriqueCCdA/bootCampAluraDataScience/master/modulo5/src/limpeza_dos_dados.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1083 (1.1K) [text/plain]
# Saving to: ‘limpeza_dos_dados.py.1’
#
# limpeza_dos_dados.p 100%[===================>]   1.06K  --.-KB/s    in 0s
#
# 2021-07-24 22:54:39 (36.4 MB/s) - ‘limpeza_dos_dados.py.1’ saved [1083/1083]

# %% [markdown]
# ## 1.2) importando os modulos

# %%
import pandas as pd
import limpeza_dos_dados as cl

# %%
dados = pd.read_excel("https://github.com/HenriqueCCdA/bootCampAluraDataScience/blob/master/modulo5/dados/Kaggle_Sirio_Libanes_ICU_Prediction.xlsx?raw=true")
dados_limpos = cl.limpando_dados(dados)
dados_limpos.head()
# Out:
#                              PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ... WINDOW  ICU
# PATIENT_VISIT_IDENTIFIER                                            ...
# 0                        0                          0            1  ...    0-2    1
# 2                        10                         2            0  ...    0-2    1
# 3                        15                         3            0  ...    0-2    0
# 4                        20                         4            0  ...    0-2    0
# 5                        25                         5            0  ...    0-2    0
#
# [5 rows x 231 columns]

# %% [markdown]
# #2) Desafio 01: Transformar a coluna AGE_PERCENTIL em dados categóricos, mas utilizando outro método.

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

dados_limpos['AGE_PERCENTIL_LABEL'] = le.fit_transform(dados_limpos.AGE_PERCENTIL)

# %%
conjunto = {}

for antigo, novo in zip(dados_limpos['AGE_PERCENTIL'] , dados_limpos['AGE_PERCENTIL_LABEL']):
  conjunto[antigo] = novo

# %%
conjunto
# Out:
# {'10th': 0,
#  '20th': 1,
#  '30th': 2,
#  '40th': 3,
#  '50th': 4,
#  '60th': 5,
#  '70th': 6,
#  '80th': 7,
#  '90th': 8,
#  'Above 90th': 9}
